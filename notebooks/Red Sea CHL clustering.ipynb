# %%
# %qtconsole

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import numpy.ma as ma

# %%
df = pd.read_csv('/Users/denis/Dropbox/repos/npz/data/chl_df.csv')
mask = np.load('/Users/denis/Dropbox/repos/npz/data/mask_land.npy')
[nlat, nlon] = mask.shape
nobs = (~mask).sum()
T = df.columns.shape[0] - 3

# %%
def to_im(vec):
    img =

# %%
chl = df.values[:, 1:-2]

# %%
from sklearn.cluster import KMeans

# %%
ms = KMeans()
ms.fit(chl)
labels = ms.labels_

# %%
scatter(df.lon, df.lat, c=labels, s = .1, alpha = .5)

# %%
scatter?
